# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

DATA_PATH = 'dataset_all.json'

LEARNING_RATE = 0.0001
EPOCHS = 50
BATCH_SIZE = 32
SAVED_MODEL_PATH = "model.h5"

NUM_KEYWORDS = 50

# %%
def load_dataset(filepath):
    with open(filepath, 'r') as fp:
        data = json.load(fp)
    X = np.array([line["mfcc"] for line in data])
    y = np.array([line["target"] for line in data])
    return X, y

# %%
def get_data_splits(data_path, test_size=0.1, test_validation=0.1):
    X, y = load_dataset(data_path)
    # X = X.T
    print(X, y, X.shape, y.shape)

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train,
                                                                    test_size=test_validation)

    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    print(X_train.shape, X_test.shape, X_validation.shape,
          y_train.shape, y_test.shape, y_validation.shape)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape, learning_rate, error="sparse_categorical_crossentropy"):
    # network
    model = keras.Sequential()

    # conv layer 1
    model.add(keras.layers.Conv2D(64, (3, 3), activation="relu",
                                  input_shape=input_shape,
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding="same"))

    # conv layer 2
    model.add(keras.layers.Conv2D(32, (3, 3), activation="relu",
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding="same"))

    # conv layer 3
    model.add(keras.layers.Conv2D(32, (2, 2), activation="relu",
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2, 2), strides=(2, 2), padding="same"))

    # flattening the output
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation="relu"))
    model.add(keras.layers.Dropout(0.3))

    # softmax
    model.add(keras.layers.Dense(NUM_KEYWORDS, activation="softmax"))

    # compiling the model
    optimiser = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimiser, loss=error, metrics=["accuracy"])

    # print model overview
    model.summary()
    return model

# %%
def main():
    X_train, X_validation, X_test, y_train, y_validation, y_test = get_data_splits(
        DATA_PATH)

    print(y_train.shape)

    # build the model
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    print(f'type of input shape {input_shape}')
    model = build_model(input_shape, LEARNING_RATE)

    # train the model
    model.fit(X_train, y_train, epochs=EPOCHS,
              validation_data=(X_validation, y_validation))

    # evaluate the model
    test_error, test_accuracy = model.evaluate(X_test, y_test)
    print(f"Test error: {test_error}, test accuracy: {test_accuracy}")

    # saving the model
    model.save(SAVED_MODEL_PATH)


if __name__ == '__main__':
    main()
# Out:
# [[[-6.03045532e+02 -6.03045532e+02 -6.03045532e+02 ... -6.03045532e+02
#    -6.03045532e+02 -6.03045532e+02]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   ...
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]
#   [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#     0.00000000e+00  0.00000000e+00]]
#
#  [[-1.92452240e+02 -2.08494217e+02 -2.32340469e+02 ... -2.65509369e+02
#    -2.58063721e+02 -2.35341324e+02]
#   [ 4.29157066e+01  5.31242065e+01  6.60339508e+01 ...  9.16070938e+01
#     9.78056183e+01  1.00034988e+02]
#   [-9.41306915e+01 -9.52263641e+01 -9.58016281e+01 ... -1.17166885e+02
#    -1.10362503e+02 -8.57419357e+01]
#   ...
#   [-1.31300564e+01 -1.35347128e+01 -1.32943859e+01 ... -5.51165676e+00
#     1.94414437e+00  4.01489258e+00]
#   [-1.30311203e+01 -9.29403877e+00 -9.80371475e+00 ... -1.34582767e+01
#    -9.50371170e+00 -5.05103159e+00]
#   [-1.18474770e+01 -8.68399525e+00 -6.26637697e+00 ... -6.41255975e-02
#     9.85853672e-01  8.05177975e+00]]
#
#  [[-1.14965767e+02 -1.03569153e+02 -1.34967834e+02 ... -2.23888454e+01
#    -2.80811844e+01 -1.92746468e+01]
#   [ 1.73043030e+02  1.66492310e+02  1.65245941e+02 ...  1.10023933e+02
#     1.00543282e+02  8.58318634e+01]
# 51/51 [==============================] - 1s 17ms/step - loss: 3.3094 - accuracy: 0.1527 - val_loss: 3.5709 - val_accuracy: 0.0667
# Epoch 5/50
# 51/51 [==============================] - 1s 17ms/step - loss: 3.1843 - accuracy: 0.1811 - val_loss: 3.4542 - val_accuracy: 0.1111
# Epoch 6/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.9513 - accuracy: 0.2532 - val_loss: 3.3312 - val_accuracy: 0.1556
# Epoch 7/50
# 51/51 [==============================] - 1s 18ms/step - loss: 2.7457 - accuracy: 0.2866 - val_loss: 3.2552 - val_accuracy: 0.2056
# Epoch 8/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.6232 - accuracy: 0.3045 - val_loss: 3.2029 - val_accuracy: 0.2167
# Epoch 9/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.4914 - accuracy: 0.3378 - val_loss: 3.1034 - val_accuracy: 0.2500
# Epoch 10/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.3196 - accuracy: 0.4047 - val_loss: 3.0831 - val_accuracy: 0.2111
# Epoch 11/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.2386 - accuracy: 0.4098 - val_loss: 3.0493 - val_accuracy: 0.2667
# Epoch 12/50
# 51/51 [==============================] - 1s 17ms/step - loss: 2.0724 - accuracy: 0.4647 - val_loss: 3.0195 - val_accuracy: 0.2389
# Epoch 13/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.9504 - accuracy: 0.4914 - val_loss: 2.9780 - val_accuracy: 0.2611
# Epoch 14/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.8590 - accuracy: 0.5187 - val_loss: 2.9660 - val_accuracy: 0.2444
# Epoch 15/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.7385 - accuracy: 0.5430 - val_loss: 2.8721 - val_accuracy: 0.2667
# Epoch 16/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.6618 - accuracy: 0.5843 - val_loss: 2.8644 - val_accuracy: 0.3000
# Epoch 17/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.5592 - accuracy: 0.5779 - val_loss: 2.8180 - val_accuracy: 0.2944
# Epoch 18/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.4320 - accuracy: 0.6327 - val_loss: 2.8558 - val_accuracy: 0.3056
# Epoch 19/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.4000 - accuracy: 0.6359 - val_loss: 2.7554 - val_accuracy: 0.3389
# Epoch 20/50
# 51/51 [==============================] - 1s 18ms/step - loss: 1.2700 - accuracy: 0.6843 - val_loss: 2.7757 - val_accuracy: 0.3167
# Epoch 21/50
# 51/51 [==============================] - 1s 18ms/step - loss: 1.2395 - accuracy: 0.6960 - val_loss: 2.7857 - val_accuracy: 0.3167
# Epoch 22/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.0819 - accuracy: 0.7398 - val_loss: 2.7386 - val_accuracy: 0.3278
# Epoch 23/50
# 51/51 [==============================] - 1s 17ms/step - loss: 1.0474 - accuracy: 0.7368 - val_loss: 2.7897 - val_accuracy: 0.3167
# Epoch 24/50
# 51/51 [==============================] - 1s 18ms/step - loss: 1.0074 - accuracy: 0.7548 - val_loss: 2.7504 - val_accuracy: 0.3222
# Epoch 25/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.9161 - accuracy: 0.7856 - val_loss: 2.7283 - val_accuracy: 0.3222
# Epoch 26/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.9044 - accuracy: 0.7984 - val_loss: 2.7600 - val_accuracy: 0.3111
# Epoch 27/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.8542 - accuracy: 0.8053 - val_loss: 2.7350 - val_accuracy: 0.3222
# Epoch 28/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.8077 - accuracy: 0.8201 - val_loss: 2.7852 - val_accuracy: 0.3000
# Epoch 29/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.7396 - accuracy: 0.8504 - val_loss: 2.7326 - val_accuracy: 0.3111
# Epoch 30/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.7153 - accuracy: 0.8522 - val_loss: 2.7469 - val_accuracy: 0.3333
# Epoch 31/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.7077 - accuracy: 0.8430 - val_loss: 2.7396 - val_accuracy: 0.3556
# Epoch 32/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.6283 - accuracy: 0.8767 - val_loss: 2.7664 - val_accuracy: 0.3111
# Epoch 33/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.6105 - accuracy: 0.8735 - val_loss: 2.7250 - val_accuracy: 0.3611
# Epoch 34/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.5525 - accuracy: 0.9002 - val_loss: 2.8430 - val_accuracy: 0.3278
# Epoch 35/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.5414 - accuracy: 0.9011 - val_loss: 2.7699 - val_accuracy: 0.3389
# Epoch 36/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.5149 - accuracy: 0.8992 - val_loss: 2.7226 - val_accuracy: 0.3500
# Epoch 37/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.5092 - accuracy: 0.8918 - val_loss: 2.7590 - val_accuracy: 0.3389
# Epoch 38/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.4830 - accuracy: 0.9027 - val_loss: 2.7389 - val_accuracy: 0.3556
# Epoch 39/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.4469 - accuracy: 0.9132 - val_loss: 2.7485 - val_accuracy: 0.3111
# Epoch 40/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.4417 - accuracy: 0.9203 - val_loss: 2.8200 - val_accuracy: 0.3056
# Epoch 41/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.4578 - accuracy: 0.9140 - val_loss: 2.8095 - val_accuracy: 0.3111
# Epoch 42/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.4008 - accuracy: 0.9376 - val_loss: 2.8090 - val_accuracy: 0.3500
# Epoch 43/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.4069 - accuracy: 0.9227 - val_loss: 2.8068 - val_accuracy: 0.3389
# Epoch 44/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3949 - accuracy: 0.9271 - val_loss: 2.8986 - val_accuracy: 0.3556
# Epoch 45/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3809 - accuracy: 0.9358 - val_loss: 2.8356 - val_accuracy: 0.3500
# Epoch 46/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3620 - accuracy: 0.9395 - val_loss: 2.8399 - val_accuracy: 0.3556
# Epoch 47/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3417 - accuracy: 0.9484 - val_loss: 2.7897 - val_accuracy: 0.3500
# Epoch 48/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3309 - accuracy: 0.9557 - val_loss: 2.7846 - val_accuracy: 0.3556
# Epoch 49/50
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3648 - accuracy: 0.9429 - val_loss: 2.8015 - val_accuracy: 0.3444
# Epoch 50/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.2999 - accuracy: 0.9560 - val_loss: 2.7952 - val_accuracy: 0.3500
# 7/7 [==============================] - 1s 208ms/step - loss: 2.6407 - accuracy: 0.3700
# Test error: 2.6406607627868652, test accuracy: 0.3700000047683716
